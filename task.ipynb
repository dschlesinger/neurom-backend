# %%
from eeg.schema import DataPoint
from eeg.data import load_data

import json

# %%
data = load_data('/home/dsch28/neurom-backend/data_store/examples.json')

# %%
data[0].model_dump_json()
# Out:
# Ser runs
# ...

# %%
with open('data_store/examples.json', 'w') as j:
    j.write(json.dumps([d.model_dump() for d in data]))
# Out:
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
