# %%
import json
from eeg.data import load_data

# %%
data = load_data('data_store/0.4 Complete.json')

# %%
data = [d for d in data if d.classification not in ['Double Right', 'Down Look']]

# %%
with open('data_store/0.4 Minecraft.json', 'w') as m:

    m.write(json.dumps([d.model_dump() for d in data]))
# Out:
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# Ser runs
# ...
